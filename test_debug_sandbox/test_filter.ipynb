# %%
from filters import ex4_rank_filter
import numpy as np

# %%
x = np.random.random((5,5))
x
# Out:
# array([[0.50001278, 0.15573259, 0.08968225, 0.36342488, 0.85763886],
#        [0.78616449, 0.43836097, 0.19301313, 0.40596419, 0.36844597],
#        [0.17749662, 0.57304518, 0.90709091, 0.12834443, 0.17417537],
#        [0.84836741, 0.73419151, 0.19286758, 0.392658  , 0.23254983],
#        [0.20269477, 0.10513903, 0.13721683, 0.23770347, 0.74261051]])

# %%
filtered_image = ex4_rank_filter(image = x, w = (3,3), filter_mode="maxTH", max_th=0.5)
# Out:
# IMAGE SHAPE: (5, 5) | PADDED IMAGE SHAPE: (7, 7) | PADDING SHAPE: (1, 1)
# Applying maxTH-Filter...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
filtered_image
# Out:
# array([[0.50001278, 0.15573259, 0.        , 0.36342488, 0.85763886],
#        [0.78616449, 0.43836097, 0.19301313, 0.40596419, 0.36844597],
#        [0.17749662, 0.57304518, 0.90709091, 0.12834443, 0.        ],
#        [0.84836741, 0.73419151, 0.19286758, 0.392658  , 0.23254983],
#        [0.20269477, 0.10513903, 0.13721683, 0.23770347, 0.74261051]])
