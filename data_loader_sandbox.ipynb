# %%
from NanTex_backend.data_preparation import img_augmentation as img_augmentation
from NanTex_backend.batching.BatchDataLoader import BatchDataLoader_Handler
# Out:
# c:\Users\belav\anaconda3\envs\NanTex\Lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
## Setup image augmentation
train_augmentation_pipeline = img_augmentation.train_augmentation_pipeline
val_augmentation_pipeline = img_augmentation.val_augmentation_pipeline

# %%
## Generate boilerplate config file
BatchDataLoader_Handler.generate_biolerplate_config_file()

# %%
## Setup BatchDataLoader
BDL:BatchDataLoader_Handler
BDL = BatchDataLoader_Handler.from_config(config_file_path=None, DEBUG=True)
 
BDL.setup_augmentation_pipelines(raw_aug = train_augmentation_pipeline, 
                                 val_aug = val_augmentation_pipeline)

train_gen, val_gen = BDL.build_BatchDataLoader()
# Out:
# Checking for configuration startup.
# Checking datatype.
# Checking configuration.
# Checking data sources.
# Setting up augmentation pipelines.
# Running checks.
# Checking configuration.
# Checking data sources.
# Checking augmentations.
# Checking datatype.
# Fetching data.
# Loading data sources.
# Loading raw data source.
# Loading validation data source.
# Building Data Loader.
# Building Data Loader.
# Not using Autobatching.
# Non-Autobatched Data Generators created.

# %%
## Check the data
#no-autobatch

import matplotlib.pyplot as plt
import numpy as np

#no-autobatch
plt.style.use('dark_background')
x,y = train_gen.dataset[0]
x,y = np.array(x), np.array(y)
print('X',np.max(x),np.min(x))
print('X_mean',np.mean(x), 'X_std', np.std(x))
print('y1',np.max(y[0,0,...]),np.min(y[0,0,...]))
print('y1_mean',np.mean(y[0,0,...]), 'y1_std', np.std(y[0,0,...]))
print('y2',np.max(y[1,0,...]),np.min(y[1,0,...]))
print('y2_mean',np.mean(y[1,0,...]), 'y2_std', np.std(y[1,0,...]))
print('y3',np.max(y[2,0,...]),np.min(y[2,0,...]))
print('y3_mean',np.mean(y[2,0,...]), 'y3_std', np.std(y[2,0,...]))
fig,ax = plt.subplots(1,4, figsize = (10,5), dpi = 200)
ax[0].imshow(x[0,0,...])
ax[0].axis('off')

ax[1].imshow(y[0,0])
ax[1].axis('off')

ax[2].imshow(y[0,1])
ax[2].axis('off')

ax[3].imshow(y[0,2])
ax[3].axis('off')
# Out:
# X 14.2267 -0.6214881
# X_mean -3.929017e-09 X_std 0.99999225
# y1 1.0 0.0
# y1_mean 0.014511228 y1_std 0.08161945
# y2 1.0 0.0
# y2_mean 0.014511228 y2_std 0.08161944
# y3 1.0 0.0
# y3_mean 0.014511229 y3_std 0.08161945
# (-0.5, 255.5, 255.5, -0.5)

# %%
## Check the data

import matplotlib.pyplot as plt
import numpy as np

## autobatch TRAIN
plt.style.use('dark_background')
x,y = train_gen.dataset[0]
x,y = np.array(x), np.array(y)
print('X',np.max(x),np.min(x))
print('X_mean',np.mean(x), 'X_std', np.std(x))
print('y1',np.max(y[0,...]),np.min(y[0,...]))
print('y1_mean',np.mean(y[0,...]), 'y1_std', np.std(y[0,...]))
print('y2',np.max(y[1,...]),np.min(y[1,...]))
print('y2_mean',np.mean(y[1,...]), 'y2_std', np.std(y[1,...]))
print('y3',np.max(y[2,...]),np.min(y[2,...]))
print('y3_mean',np.mean(y[2,...]), 'y3_std', np.std(y[2,...]))
fig,ax = plt.subplots(1,4, figsize = (10,5), dpi = 200)
ax[0].imshow(x[0,...])
ax[0].axis('off')

ax[1].imshow(y[0])
ax[1].axis('off')

ax[2].imshow(y[1])
ax[2].axis('off')

ax[3].imshow(y[2])
ax[3].axis('off')
# Out:
# X 12.845114 -0.6218583
# X_mean 1.5774276e-08 X_std 0.999992
# y1 1.0 0.0
# y1_mean 0.043914583 y1_std 0.13200623
# y2 1.0 0.0
# y2_mean 0.043914586 y2_std 0.13200623
# y3 1.0 0.0
# y3_mean 0.043914586 y3_std 0.13200623
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 19
#      17 print('y3_mean',np.mean(y[2,...]), 'y3_std', np.std(y[2,...]))
#      18 fig,ax = plt.subplots(1,4, figsize = (10,5), dpi = 200)
# ---> 19 ax[0].imshow(x[0,...])
#      20 ax[0].axis('off')
#      22 ax[1].imshow(y[0])
#
# File c:\Users\belav\anaconda3\envs\NanTex\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\belav\anaconda3\envs\NanTex\Lib\site-packages\matplotlib\axes\_axes.py:5895, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5892 if aspect is not None:
#    5893     self.set_aspect(aspect)
# -> 5895 im.set_data(X)
#    5896 im.set_alpha(alpha)
#    5897 if im.get_clip_path() is None:
#    5898     # image does not already have clipping set, clip to Axes patch
#
# File c:\Users\belav\anaconda3\envs\NanTex\Lib\site-packages\matplotlib\image.py:729, in _ImageBase.set_data(self, A)
#     727 if isinstance(A, PIL.Image.Image):
#     728     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 729 self._A = self._normalize_image_array(A)
#     730 self._imcache = None
#     731 self.stale = True
#
# File c:\Users\belav\anaconda3\envs\NanTex\Lib\site-packages\matplotlib\image.py:697, in _ImageBase._normalize_image_array(A)
#     695     A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     696 if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 697     raise TypeError(f"Invalid shape {A.shape} for image data")
#     698 if A.ndim == 3:
#     699     # If the input data has values outside the valid range (after
#     700     # normalisation), we issue a warning and then clip X to the bounds
#     701     # - otherwise casting wraps extreme values, hiding outliers and
#     702     # making reliable interpretation impossible.
#     703     high = 255 if np.issubdtype(A.dtype, np.integer) else 1
#
# TypeError: Invalid shape (1, 256, 256) for image data
